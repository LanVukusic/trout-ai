# %% [markdown]
# load lichess dataset if it does not exist yet.

# %%
import os

DATA_URL = "https://database.lichess.org/standard/lichess_db_standard_rated_2017-09.pgn.zst"
OUT_FILE = "lichess_data.pgn.zst"

# download if not exists
if not os.path.exists(OUT_FILE):
    # !wget -O $OUT_FILE $DATA_URL

# unzip
if not os.path.exists(OUT_FILE[:-4]):
    # !zstd -d $OUT_FILE

# %%
# use python chess library to parse the pgn file

import chess.pgn
import random

# import local descriptions lib
from descriptions import generate_captures_texts
from descriptions import generate_checks_texts
from descriptions import generate_pinned_texts

SAMPLE_CHANCE = 1

with open(OUT_FILE[:-4]) as pgn:
    game = chess.pgn.read_game(pgn)
    while game:
        # print(game.headers["White"], game.headers["Black"], game.headers["Result"])
        boards = []

        board = game.board()
        for i, move in enumerate(game.mainline_moves()):
          # input chess move to board
          board.push(move)
          if random.random() < SAMPLE_CHANCE:
            boards.append(board.copy())

        for board in boards:
          # input chess move to board
          # print(generate_captures_texts(board, include_pawns=False))
          # print(generate_checks_texts(board))
          # print(generate_pinned_texts(board))

          descriptions = []
          descriptions.extend(generate_captures_texts(board, include_pawns=False))
          descriptions.extend(generate_checks_texts(board))
          descriptions.extend(generate_pinned_texts(board))

          # pick 5 random descriptions
          random.shuffle(descriptions)
          descriptions = descriptions[:5]

          print(descriptions)


        # read next game
        game = chess.pgn.read_game(pgn)
# Out:
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White  queen on f3 can capture Black knight on f6.']
# ['Black knight on f6 can check White king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White  queen on f3 can capture Black knight on f6.', 'Black knight on f6 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.']
# ['Black queen on d8 can check White king.', 'White  queen on f3 can capture Black knight on f6.', 'Black knight on f6 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White  queen on f3 can capture Black knight on f6.']
# ['Black queen on d8 can check White king.', 'Black  knight on f6 can capture White knight on e4.', 'Black knight on f6 can check White king.']
# ['Black knight on f6 can check White king.', 'Black queen on d8 can check White king.', 'White  knight on e4 can capture Black knight on f6.', 'Black rook on h8 can check White king.', 'White  queen on f3 can capture Black knight on f6.']
# ['Black  knight on d7 can capture White knight on f6.', 'Black  pawn on g7 can capture White knight on f6.', 'Black rook on h8 can check White king.', 'Black  bishop on e7 can capture White knight on f6.', 'Black queen on d8 can check White king.']
# ['Black rook on h8 can check White king.', 'Black queen on d8 can check White king.']
# ['Black pawn on f7 is pinned.', 'Black queen on d8 can check White king.', 'Black rook on h8 can check White king.']
# ['Black rook on h8 can check White king.', 'Black pawn on f7 is pinned.']
# ['Black rook on h8 can check White king.']
# ['Black rook on h8 can check White king.', 'Black bishop on e7 can check White king.', 'Black queen on c7 can check White king.', 'White  queen on f7 can capture Black bishop on e7.']
# ['Black rook on h8 can check White king.', 'Black bishop on e7 can check White king.', 'Black queen on c7 can check White king.', 'White rook on a1 can check Black king.']
# ['Black queen on c7 can check White king.', 'White rook on a1 can check Black king.', 'White  queen on f7 can capture Black bishop on e7.', 'Black bishop on e7 can check White king.', 'White  queen on f7 can capture Black rook on f8.']
# ['Black queen on c7 can check White king.', 'Black bishop on e7 can check White king.', 'White rook on a1 can check Black king.', 'Black rook on f8 can check White king.']
# ['White  queen on g7 can capture Black bishop on e7.', 'White  queen on g7 can capture Black rook on f8.', 'Black bishop on e7 can check White king.', 'White rook on a1 can check Black king.', 'Black rook on f8 can check White king.']
# ['Black bishop on e7 can check White king.', 'Black rook on f8 can check White king.', 'Black  rook on f8 can capture White bishop on f7.', 'Black queen on c7 can check White king.', 'White rook on a1 can check Black king.']
# ['White rook on a1 can check Black king.', 'Black rook on f8 can check White king.', 'White  queen on g7 can capture Black rook on f8.', 'Black queen on c7 can check White king.', 'Black bishop on e7 can check White king.']
# ['Black rook on f8 can check White king.', 'Black bishop on e7 can check White king.', 'White rook on a1 can check Black king.', 'Black queen on c7 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.']
# ['Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['Black knight on f6 can check White king.', 'White knight on f3 can check Black king.', 'Black rook on h8 can check White king.', 'Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White queen on d1 can check Black king.', 'White knight on f3 can check Black king.', 'Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'Black rook on h8 can check White king.']
# ['Black queen on d8 can check White king.', 'White  bishop on g5 can capture Black knight on f6.', 'Black rook on h8 can check White king.', 'Black knight on f6 can check White king.', 'White queen on d1 can check Black king.']
# ['White rook on h1 can check Black king.', 'White queen on d1 can check Black king.', 'Black knight on f6 can check White king.', 'Black queen on d8 can check White king.', 'White knight on f3 can check Black king.']
# ['White rook on h1 can check Black king.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.', 'Black rook on f8 can check White king.', 'Black knight on f6 can check White king.']
# ['Black  pawn on g7 can capture White bishop on f6.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.', 'White rook on h1 can check Black king.', 'Black rook on f8 can check White king.']
# ['White rook on h1 can check Black king.', 'White knight on f3 can check Black king.', 'Black rook on e8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black  rook on e8 can capture White bishop on e5.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.', 'White bishop on e5 is pinned.', 'Black rook on e8 can check White king.']
# ['White rook on h1 can check Black king.', 'White queen on d1 can check Black king.', 'White bishop on e5 is pinned.', 'Black rook on e8 can check White king.', 'White knight on f3 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  pawn on f6 can capture White bishop on e5.', 'White knight on f3 can check Black king.', 'Black  rook on e8 can capture White bishop on e5.', 'Black rook on e8 can check White king.']
# ['White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black rook on e8 can check White king.']
# ['Black rook on e8 can check White king.', 'White rook on f1 can check Black king.', 'White knight on f3 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black rook on e8 can check White king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.']
# ['Black rook on e8 can check White king.', 'White rook on f1 can check Black king.', 'White pawn on f2 is pinned.', 'White knight on f3 can check Black king.', 'White knight on e2 can check Black king.']
# ['White rook on f1 can check Black king.', 'White pawn on f2 is pinned.', 'White knight on f3 can check Black king.', 'White knight on e2 can check Black king.', 'Black rook on e8 can check White king.']
# ['White pawn on f2 is pinned.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'White knight on e2 can check Black king.', 'Black rook on e8 can check White king.']
# ['White  pawn on g2 can capture Black bishop on f3.', 'White knight on e2 can check Black king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black rook on e8 can check White king.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'White knight on e2 can check Black king.', 'Black rook on e8 can check White king.']
# ['White rook on f1 can check Black king.', 'White knight on e2 can check Black king.', 'White pawn on f2 is pinned.', 'Black queen on d8 can check White king.']
# ['White rook on f1 can check Black king.', 'Black queen on d8 can check White king.', 'White pawn on f2 is pinned.']
# ['White rook on f1 can check Black king.', 'White knight on g3 is pinned.', 'White pawn on f2 is pinned.', 'Black queen on d8 can check White king.']
# ['White pawn on f2 is pinned.', 'White knight on g3 is pinned.', 'Black  rook on g5 can capture White knight on g3.', 'Black queen on d8 can check White king.', 'White rook on f1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White rook on f1 can check Black king.', 'White knight on g3 is pinned.', 'White pawn on f2 is pinned.']
# ['White rook on f1 can check Black king.', 'Black queen on d8 can check White king.', 'Black  rook on g5 can capture White knight on g3.', 'White pawn on f2 is pinned.', 'White knight on g3 is pinned.']
# ['White pawn on f2 is pinned.', 'Black queen on d8 can check White king.', 'White rook on f1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White rook on f1 can check Black king.', 'White pawn on f2 is pinned.']
# ['White rook on f1 can check Black king.', 'White pawn on f2 is pinned.']
# ['White rook on f1 can check Black king.', 'White pawn on f2 is pinned.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black pawn on g7 is pinned.']
# ['White rook on f1 can check Black king.', 'White pawn on f2 is pinned.']
# ['Black pawn on g7 is pinned.', 'White rook on f1 can check Black king.', 'White pawn on f2 is pinned.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'White pawn on f2 is pinned.', 'Black bishop on c5 can check White king.']
# ['Black bishop on c5 can check White king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.']
# ['White pawn on f2 is pinned.', 'White  queen on h8 can capture Black knight on b8.', 'White rook on f1 can check Black king.']
# ['Black pawn on g7 is pinned.', 'Black  queen on h4 can capture White knight on g3.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black pawn on g7 is pinned.']
# ['White rook on f1 can check Black king.', 'Black pawn on g7 is pinned.', 'Black  rook on e5 can capture White rook on e1.', 'Black  queen on h4 can capture White knight on g3.', 'White pawn on f2 is pinned.']
# ['White  rook on e1 can capture Black rook on e5.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black pawn on g7 is pinned.']
# ['White rook on f1 can check Black king.', 'White pawn on f2 is pinned.']
# ['Black rook on e8 can check White king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'White  rook on e1 can capture Black rook on e5.', 'Black queen on h4 can check White king.']
# ['Black rook on e8 can check White king.', 'White rook on f1 can check Black king.', 'White pawn on f2 is pinned.', 'Black rook on e5 can check White king.', 'Black bishop on c5 can check White king.']
# ['White  rook on e1 can capture Black rook on e5.', 'White  knight on f5 can capture Black queen on h4.', 'White  queen on g6 can capture Black rook on e8.', 'White queen on g6 can check Black king.', 'White pawn on f2 is pinned.']
# ['Black  rook on e5 can capture White rook on e1.', 'White queen on g6 can check Black king.', 'Black rook on e8 can check White king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.']
# ['Black rook on e8 can check White king.', 'White rook on f1 can check Black king.', 'White queen on g6 can check Black king.', 'White  rook on e1 can capture Black rook on e5.', 'White  queen on g6 can capture Black rook on e8.']
# ['White rook on f1 can check Black king.', 'Black  knight on d7 can capture White rook on e5.', 'Black rook on e8 can check White king.', 'White queen on g6 can check Black king.', 'Black  rook on e8 can capture White rook on e5.']
# ['White rook on f1 can check Black king.', 'White  queen on g6 can capture Black rook on e8.', 'White queen on g6 can check Black king.', 'Black rook on e8 can check White king.']
# ['White rook on f1 can check Black king.', 'White queen on g5 can check Black king.', 'Black rook on e8 can check White king.']
# ['White rook on f1 can check Black king.', 'White  queen on g5 can capture Black knight on e5.', 'White queen on g5 can check Black king.']
# ['Black  rook on e8 can capture White queen on e5.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.', 'White knight on f3 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.', 'White knight on f3 can check Black king.']
# ['Black  bishop on g7 can capture White knight on d4.', 'White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'White  knight on d4 can capture Black knight on c6.']
# ['Black  pawn on b7 can capture White knight on c6.', 'Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'Black  pawn on d7 can capture White knight on c6.', 'Black  bishop on g7 can capture White knight on c3.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black  bishop on g7 can capture White knight on c3.', 'Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White queen on d1 can check Black king.', 'Black rook on h8 can check White king.']
# ['White queen on d1 can check Black king.', 'Black rook on h8 can check White king.', 'Black knight on f6 can check White king.', 'Black queen on d8 can check White king.']
# ['Black rook on f8 can check White king.', 'White queen on d1 can check Black king.', 'Black knight on f6 can check White king.']
# ['White queen on d2 can check Black king.', 'Black knight on f6 can check White king.', 'White rook on a1 can check Black king.', 'Black rook on f8 can check White king.']
# ['Black rook on f8 can check White king.', 'Black knight on f6 can check White king.', 'White rook on a1 can check Black king.', 'White queen on d2 can check Black king.']
# ['Black knight on f6 can check White king.', 'White rook on a1 can check Black king.', 'White queen on d2 can check Black king.', 'Black rook on f8 can check White king.']
# ['White rook on a1 can check Black king.', 'Black rook on f8 can check White king.', 'White queen on d2 can check Black king.', 'Black knight on f6 can check White king.']
# ['White queen on d2 can check Black king.', 'White rook on a1 can check Black king.', 'Black rook on f8 can check White king.', 'Black knight on f6 can check White king.']
# ['Black knight on f6 can check White king.', 'Black rook on f8 can check White king.', 'White queen on d2 can check Black king.', 'White rook on a1 can check Black king.']
# ['White rook on a1 can check Black king.', 'Black knight on f6 can check White king.', 'White rook on h1 can check Black king.', 'Black rook on f8 can check White king.', 'White queen on d2 can check Black king.']
# ['White rook on a1 can check Black king.', 'White rook on h1 can check Black king.', 'White queen on d2 can check Black king.', 'White  knight on c3 can capture Black knight on d5.', 'Black rook on f8 can check White king.']
# ['White rook on a1 can check Black king.', 'Black  bishop on b7 can capture White knight on d5.', 'Black rook on f8 can check White king.', 'White rook on h1 can check Black king.', 'White queen on d2 can check Black king.']
# ['Black rook on f8 can check White king.', 'White rook on a1 can check Black king.', 'White queen on d2 can check Black king.', 'White rook on h1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black rook on f8 can check White king.']
# ['White rook on f1 can check Black king.', 'Black rook on f8 can check White king.']
# ['Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'Black  bishop on g7 can capture White bishop on h6.']
# ['Black rook on f8 can check White king.', 'White  queen on d2 can capture Black rook on b2.', 'White  bishop on h6 can capture Black bishop on g7.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  bishop on g7 can capture White queen on b2.', 'Black rook on f8 can check White king.', 'Black  bishop on g7 can capture White bishop on h6.']
# ['White rook on f1 can check Black king.', 'White  bishop on h6 can capture Black rook on f8.', 'Black rook on f8 can check White king.']
# ['White rook on f1 can check Black king.', 'Black rook on f8 can check White king.']
# ['White  bishop on h6 can capture Black bishop on g7.', 'White rook on f1 can check Black king.', 'Black rook on f8 can check White king.']
# ['Black  king on g8 can capture White bishop on g7.', 'Black rook on f8 can check White king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White  rook on b5 can capture Black bishop on d5.', 'White rook on f1 can check Black king.']
# ['White rook on b1 can check Black king.']
# ['White rook on b1 can check Black king.', 'White  rook on b5 can capture Black bishop on d5.']
# ['White rook on b1 can check Black king.']
# ['White rook on b1 can check Black king.', 'White  rook on b5 can capture Black bishop on d5.']
# ['White rook on b1 can check Black king.']
# ['White  bishop on e2 can capture Black bishop on c4.', 'White rook on b1 can check Black king.']
# ['Black  queen on c7 can capture White bishop on c4.', 'White rook on b1 can check Black king.']
# ['White rook on b1 can check Black king.']
# ['Black pawn on f7 is pinned.', 'White rook on b1 can check Black king.']
# ['White  rook on b7 can capture Black rook on c7.', 'White rook on b1 can check Black king.']
# ['Black  queen on c4 can capture White rook on b4.', 'White rook on b1 can check Black king.']
# ['White rook on b1 can check Black king.']
# ['White rook on b1 can check Black king.', 'Black  queen on a2 can capture White rook on b1.']
# ['White rook on b1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on a2 can capture White rook on b1.']
# ['White rook on f1 can check Black king.']
# ['Black  queen on a2 can capture White rook on a1.', 'White rook on f1 can check Black king.']
# ['Black queen on b2 can check White king.', 'White rook on f1 can check Black king.']
# ['Black queen on b2 can check White king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black queen on c3 can check White king.']
# ['White rook on f1 can check Black king.', 'Black queen on c3 can check White king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on c3 can capture White rook on e1.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['Black queen on c3 can check White king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on c3 can capture White rook on e1.', 'Black queen on c3 can check White king.']
# ['Black queen on c3 can check White king.', 'White rook on f1 can check Black king.']
# ['Black queen on c3 can check White king.', 'White rook on f1 can check Black king.', 'Black  queen on c3 can capture White rook on e1.']
# ['White rook on f1 can check Black king.', 'Black queen on c3 can check White king.']
# ['Black queen on c3 can check White king.', 'White pawn on g2 is pinned.', 'Black  queen on c3 can capture White rook on e1.']
# ['Black queen on c3 can check White king.', 'White  king on h2 can capture Black rook on g2.']
# ['Black  queen on c3 can capture White rook on e1.', 'Black queen on c3 can check White king.']
# []
# ['White rook on f1 can check Black king.', 'Black  queen on d2 can capture White rook on e1.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on d2 can capture White rook on d1.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on e2 can capture White rook on e1.', 'Black  queen on e2 can capture White rook on f1.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on d2 can capture White rook on d1.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on c2 can capture White rook on d1.']
# ['White rook on f1 can check Black king.', 'Black queen on f5 can check White king.']
# ['Black queen on f5 can check White king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on h3 can capture White rook on f1.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on g3 can capture White rook on g2.', 'White rook on g2 is pinned.', 'White rook on g2 can check Black king.']
# ['White rook on f1 can check Black king.', 'White rook on g2 can check Black king.']
# ['Black  queen on h3 can capture White rook on f1.', 'Black  queen on h3 can capture White rook on h2.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black queen on f5 can check White king.']
# ['White rook on g2 can check Black king.', 'White rook on f1 can check Black king.', 'Black queen on f5 can check White king.']
# ['White rook on f1 can check Black king.', 'Black queen on f5 can check White king.', 'White rook on g2 can check Black king.']
# ['Black queen on f5 can check White king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on g2 can check Black king.', 'Black  queen on d3 can capture White rook on f1.', 'White rook on f1 can check Black king.']
# ['White rook on g2 can check Black king.', 'White rook on f1 can check Black king.']
# ['Black  queen on d3 can capture White rook on e2.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['Black  queen on e2 can capture White rook on f2.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.']
# ['Black knight on d7 is pinned.', 'White knight on f3 can check Black king.', 'White rook on h1 can check Black king.', 'White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black knight on d7 is pinned.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.', 'Black queen on d8 can check White king.', 'White rook on h1 can check Black king.']
# ['Black queen on d8 can check White king.', 'Black  bishop on b7 can capture White knight on e4.', 'White queen on e2 can check Black king.', 'White knight on f3 can check Black king.', 'White rook on h1 can check Black king.']
# ['White rook on h1 can check Black king.', 'White knight on f3 can check Black king.', 'Black queen on d8 can check White king.', 'Black knight on d7 is pinned.', 'White  bishop on b5 can capture Black knight on d7.']
# ['White rook on h1 can check Black king.', 'White queen on e2 can check Black king.', 'Black  bishop on b7 can capture White knight on e4.', 'Black knight on d7 is pinned.', 'White knight on f3 can check Black king.']
# ['White queen on e2 can check Black king.', 'Black queen on d8 can check White king.', 'White rook on h1 can check Black king.', 'White knight on f3 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black queen on d8 can check White king.', 'White rook on h1 can check Black king.', 'Black  bishop on b7 can capture White knight on e4.', 'White queen on e2 can check Black king.']
# ['White  knight on e4 can capture Black knight on f6.', 'White queen on e2 can check Black king.', 'Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'Black knight on f6 can check White king.']
# ['White rook on h1 can check Black king.', 'White queen on e2 can check Black king.', 'Black pawn on e6 is pinned.', 'Black  bishop on b7 can capture White knight on f3.', 'Black queen on d8 can check White king.']
# ['White queen on e2 can check Black king.', 'Black pawn on e6 is pinned.', 'White knight on f3 can check Black king.', 'White rook on h1 can check Black king.', 'Black knight on f6 can check White king.']
# ['White queen on e2 can check Black king.', 'Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'Black knight on f6 can check White king.', 'White rook on h1 can check Black king.']
# ['White rook on h1 can check Black king.', 'Black rook on h8 can check White king.', 'Black knight on f6 can check White king.', 'White queen on e2 can check Black king.', 'Black pawn on e6 is pinned.']
# ['Black rook on h8 can check White king.', 'Black queen on d8 can check White king.', 'White rook on h1 can check Black king.', 'Black  bishop on b7 can capture White knight on f3.', 'White knight on f3 can check Black king.']
# ['White  bishop on g5 can capture Black knight on f6.', 'Black rook on h8 can check White king.', 'White knight on f3 can check Black king.', 'White rook on h1 can check Black king.', 'Black knight on f6 can check White king.']
# ['Black rook on h8 can check White king.', 'White pawn on f2 is pinned.', 'Black  bishop on b7 can capture White knight on f3.', 'Black knight on f6 can check White king.', 'Black rook on a8 can check White king.']
# ['Black rook on f8 can check White king.', 'White  bishop on g5 can capture Black knight on f6.', 'Black knight on f6 can check White king.', 'White knight on f3 can check Black king.', 'White pawn on f2 is pinned.']
# ['Black  bishop on b7 can capture White knight on f3.', 'White knight on f3 can check Black king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.']
# ['White  rook on d1 can capture Black knight on d7.', 'White pawn on f2 is pinned.', 'White  bishop on g5 can capture Black knight on f6.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.']
# ['Black rook on f8 can check White king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black  pawn on g7 can capture White bishop on f6.', 'Black  bishop on b7 can capture White knight on f3.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'Black knight on f6 can check White king.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.', 'Black rook on f8 can check White king.']
# ['White rook on f1 can check Black king.', 'White  rook on d1 can capture Black rook on d8.', 'White pawn on f2 is pinned.', 'Black rook on d8 can check White king.', 'Black knight on f6 can check White king.']
# ['Black  rook on a8 can capture White rook on d8.', 'White pawn on f2 is pinned.', 'Black knight on f6 can check White king.', 'Black  queen on b6 can capture White rook on d8.', 'White rook on f1 can check Black king.']
# ['White pawn on f2 is pinned.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.', 'Black rook on d8 can check White king.']
# ['Black rook on d8 can check White king.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.', 'White pawn on f2 is pinned.']
# ['White rook on f1 can check Black king.', 'Black knight on f6 can check White king.', 'Black rook on d8 can check White king.', 'White pawn on f2 is pinned.']
# ['Black knight on f6 can check White king.', 'White rook on f1 can check Black king.', 'Black rook on d8 can check White king.', 'White pawn on f2 is pinned.']
# ['White rook on f1 can check Black king.', 'White pawn on f2 is pinned.', 'Black knight on f6 can check White king.', 'Black rook on d8 can check White king.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black rook on d8 can check White king.', 'Black knight on f6 can check White king.']
# ['Black rook on d8 can check White king.', 'White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.']
# ['White pawn on f2 is pinned.', 'Black knight on f6 can check White king.', 'Black rook on d8 can check White king.', 'White rook on f1 can check Black king.']
# ['White pawn on f2 is pinned.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.', 'Black rook on d8 can check White king.']
# ['White pawn on f2 is pinned.', 'Black rook on d8 can check White king.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.']
# ['White pawn on f2 is pinned.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.', 'Black rook on d8 can check White king.']
# ['Black rook on d8 can check White king.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.', 'White pawn on f2 is pinned.']
# ['White pawn on f2 is pinned.', 'White rook on f1 can check Black king.', 'White  queen on c4 can capture Black bishop on c5.', 'Black knight on f6 can check White king.', 'White  queen on c4 can capture Black bishop on a6.']
# ['Black rook on d8 can check White king.', 'Black  bishop on a6 can capture White rook on f1.', 'White pawn on f2 is pinned.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.']
# ['Black knight on f6 can check White king.', 'White  king on g1 can capture Black bishop on f1.', 'Black rook on d8 can check White king.', 'White pawn on f2 is pinned.', 'White  knight on g3 can capture Black bishop on f1.']
# ['Black knight on f6 can check White king.', 'White knight on g3 can check Black king.', 'Black rook on d8 can check White king.']
# ['Black knight on f6 can check White king.', 'White knight on g3 can check Black king.', 'Black rook on d8 can check White king.']
# ['Black  knight on f6 can capture White knight on e4.', 'Black rook on d8 can check White king.', 'Black knight on f6 can check White king.']
# ['Black rook on d8 can check White king.', 'White  queen on a4 can capture Black knight on e4.']
# ['Black rook on d8 can check White king.']
# []
# ['White queen on e4 can check Black king.']
# ['White queen on e4 can check Black king.', 'White  king on e2 can capture Black rook on d1.']
# ['White knight on e5 can check Black king.', 'Black  queen on b2 can capture White bishop on a2.', 'White queen on e4 can check Black king.', 'White pawn on g2 can check Black king.']
# ['White knight on e5 can check Black king.', 'White pawn on g2 can check Black king.', 'White queen on e4 can check Black king.']
# ['White queen on b7 can check Black king.', 'White pawn on g2 can check Black king.', 'White knight on e5 can check Black king.']
# ['White  queen on b7 can capture Black queen on d5.', 'White knight on e5 can check Black king.', 'White pawn on g2 can check Black king.', 'White  king on f3 can capture Black bishop on f2.']
# ['Black  pawn on e6 can capture White queen on d5.', 'Black  rook on d1 can capture White queen on d5.', 'White pawn on g2 can check Black king.', 'White knight on e5 can check Black king.', 'White queen on d5 can check Black king.']
# ['White pawn on g2 can check Black king.', 'White  king on f3 can capture Black bishop on f2.', 'White knight on e5 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White pawn on c3 is pinned.', 'Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'Black rook on h8 can check White king.']
# ['Black rook on h8 can check White king.', 'Black knight on f6 can check White king.', 'White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black rook on h8 can check White king.', 'White queen on d1 can check Black king.', 'Black queen on d8 can check White king.', 'Black bishop on d7 can check White king.', 'Black knight on f6 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'White knight on f3 can check Black king.', 'White rook on h1 can check Black king.', 'Black knight on f6 can check White king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'Black rook on h8 can check White king.', 'Black bishop on d7 can check White king.']
# ['Black knight on f6 can check White king.', 'Black bishop on d7 can check White king.', 'White rook on f1 can check Black king.', 'Black rook on h8 can check White king.', 'Black queen on d8 can check White king.']
# ['White rook on f1 can check Black king.', 'Black knight on f6 can check White king.', 'Black bishop on d7 can check White king.', 'Black rook on h8 can check White king.', 'Black queen on d8 can check White king.']
# ['Black bishop on d7 can check White king.', 'Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.']
# ['Black rook on a8 can check White king.', 'Black queen on e7 can check White king.', 'White rook on f1 can check Black king.', 'White knight on f3 can check Black king.', 'Black bishop on d7 can check White king.']
# ['White rook on f1 can check Black king.', 'Black queen on e7 can check White king.', 'Black rook on h8 can check White king.', 'Black bishop on d7 can check White king.', 'Black knight on f6 can check White king.']
# ['Black rook on h8 can check White king.', 'White knight on f3 can check Black king.', 'Black knight on f6 can check White king.', 'Black bishop on d7 can check White king.', 'White rook on f1 can check Black king.']
# ['Black knight on f6 can check White king.', 'Black rook on h8 can check White king.', 'Black queen on e7 can check White king.', 'White knight on f3 can check Black king.', 'Black bishop on d7 can check White king.']
# ['Black rook on d8 can check White king.', 'White  queen on g7 can capture Black knight on f6.', 'White rook on f1 can check Black king.', 'White  queen on g7 can capture Black rook on h8.', 'White knight on f3 can check Black king.']
# ['Black bishop on d7 can check White king.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black rook on d8 can check White king.']
# ['White  queen on g3 can capture Black rook on g8.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black bishop on d7 can check White king.', 'Black rook on g8 can check White king.']
# ['White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'White pawn on g2 is pinned.', 'Black bishop on d7 can check White king.', 'Black rook on g8 can check White king.']
# ['Black rook on g8 can check White king.', 'Black bishop on d7 can check White king.', 'White knight on f3 can check Black king.', 'White queen on f2 can check Black king.', 'White rook on f1 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black rook on g8 can check White king.', 'Black bishop on d7 can check White king.', 'White rook on f1 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black bishop on d7 can check White king.', 'White rook on f1 can check Black king.', 'White pawn on g2 is pinned.', 'Black rook on g8 can check White king.']
# ['White pawn on g2 is pinned.', 'White rook on f1 can check Black king.', 'Black bishop on d7 can check White king.', 'Black rook on g8 can check White king.']
# ['White pawn on g2 is pinned.', 'Black rook on g8 can check White king.', 'White rook on f1 can check Black king.', 'Black bishop on d7 can check White king.']
# ['Black rook on g8 can check White king.', 'White rook on f1 can check Black king.', 'Black  queen on h4 can capture White knight on h2.', 'White knight on f3 can check Black king.', 'Black bishop on d7 can check White king.']
# ['White pawn on g2 is pinned.', 'Black rook on g8 can check White king.', 'Black bishop on d7 can check White king.', 'White rook on f1 can check Black king.', 'White knight on f3 can check Black king.']
# ['White queen on f2 can check Black king.', 'White knight on f3 can check Black king.', 'Black  queen on g3 can capture White knight on f3.', 'Black bishop on d7 can check White king.', 'Black rook on g8 can check White king.']
# ['White pawn on g2 is pinned.', 'White knight on f3 can check Black king.', 'Black bishop on d7 can check White king.', 'Black rook on g8 can check White king.', 'White queen on f2 can check Black king.']
# ['Black bishop on d7 can check White king.', 'Black rook on g8 can check White king.', 'White pawn on g2 is pinned.', 'Black  bishop on d6 can capture White knight on e5.', 'White queen on f2 can check Black king.']
# ['White queen on f2 can check Black king.', 'White pawn on g2 is pinned.', 'Black bishop on d7 can check White king.', 'White  pawn on f4 can capture Black bishop on e5.', 'White  pawn on d4 can capture Black bishop on e5.']
# ['White rook on f1 can check Black king.', 'Black bishop on d7 can check White king.', 'White pawn on g2 is pinned.', 'Black rook on g8 can check White king.', 'White queen on f2 can check Black king.']
# ['Black rook on g8 can check White king.', 'Black bishop on d7 can check White king.', 'White rook on f1 can check Black king.', 'White pawn on g2 is pinned.', 'White queen on f2 can check Black king.']
# ['White rook on f1 can check Black king.', 'White queen on f2 can check Black king.', 'Black rook on g8 can check White king.', 'White pawn on g2 is pinned.', 'Black bishop on d7 can check White king.']
# ['White pawn on g2 is pinned.', 'Black rook on g8 can check White king.', 'White queen on f2 can check Black king.', 'Black bishop on d7 can check White king.', 'White rook on f1 can check Black king.']
# ['Black rook on g8 can check White king.', 'White queen on f2 can check Black king.', 'Black bishop on d7 can check White king.', 'White pawn on g2 is pinned.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black rook on g8 can check White king.', 'Black bishop on d7 can check White king.', 'White pawn on g2 is pinned.', 'White queen on f2 can check Black king.']
# ['Black  bishop on d7 can capture White bishop on f5.', 'Black bishop on d7 can check White king.', 'Black bishop on d7 is pinned.', 'White queen on f2 can check Black king.', 'White rook on f1 can check Black king.']
# ['White pawn on g2 is pinned.', 'Black bishop on f5 can check White king.', 'Black rook on g8 can check White king.', 'White queen on f2 can check Black king.', 'White  queen on f2 can capture Black bishop on f5.']
# ['White rook on f1 can check Black king.', 'Black rook on g8 can check White king.', 'White pawn on g2 is pinned.']
# ['Black knight on c6 can check White king.', 'Black rook on g8 can check White king.', 'White pawn on g2 is pinned.', 'White rook on f1 can check Black king.']
# ['Black rook on g8 can check White king.', 'White pawn on g2 is pinned.', 'Black knight on c6 can check White king.', 'White rook on f1 can check Black king.']
# ['Black knight on c6 can check White king.', 'Black rook on g8 can check White king.', 'White pawn on g2 is pinned.', 'White rook on f1 can check Black king.']
# ['Black rook on g8 can check White king.', 'Black knight on c6 can check White king.', 'White rook on f1 can check Black king.', 'White pawn on g3 is pinned.']
# ['White rook on f1 can check Black king.', 'Black rook on g8 can check White king.', 'White queen on g3 is pinned.', 'White  queen on f3 can capture Black queen on g3.', 'Black knight on c6 can check White king.']
# ['White queen on g3 can check Black king.', 'Black knight on c6 can check White king.', 'Black  rook on g8 can capture White queen on g3.', 'Black rook on g8 can check White king.', 'White rook on f1 can check Black king.']
# ['Black knight on c6 can check White king.', 'Black rook on h8 can check White king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black rook on h8 can check White king.', 'Black knight on c6 can check White king.']
# ['Black knight on c6 can check White king.', 'Black rook on h8 can check White king.', 'White rook on f1 can check Black king.']
# ['Black  rook on g2 can capture White knight on h2.', 'White rook on g1 can check Black king.', 'Black knight on c6 can check White king.', 'Black  rook on g2 can capture White rook on g1.', 'Black rook on h8 can check White king.']
# ['Black knight on c6 can check White king.', 'Black rook on g8 can check White king.', 'White rook on g1 can check Black king.', 'White  rook on g1 can capture Black rook on g2.']
# ['Black  rook on g2 can capture White rook on g1.', 'Black knight on c6 can check White king.', 'Black rook on g8 can check White king.', 'Black  rook on g2 can capture White knight on h2.', 'White rook on g1 can check Black king.']
# ['White rook on g1 can check Black king.', 'Black rook on g8 can check White king.', 'White  rook on g1 can capture Black rook on g2.']
# ['Black rook on g8 can check White king.', 'Black  rook on g2 can capture White knight on h2.', 'White rook on g1 can check Black king.', 'Black  rook on g2 can capture White rook on g1.']
# ['Black rook on g8 can check White king.', 'White  rook on g1 can capture Black rook on g2.', 'White rook on g1 can check Black king.']
# ['Black rook on g8 can check White king.', 'Black  rook on g2 can capture White rook on g1.', 'Black  rook on g2 can capture White knight on h2.', 'White rook on g1 can check Black king.']
# ['White  rook on g1 can capture Black rook on g2.', 'White rook on g1 can check Black king.', 'Black rook on g8 can check White king.']
# ['White rook on g1 can check Black king.', 'Black  rook on g2 can capture White knight on h2.', 'Black  rook on g2 can capture White rook on g1.', 'Black rook on g8 can check White king.']
# ['White rook on g1 can check Black king.', 'White  bishop on f4 can capture Black rook on h2.', 'Black rook on g8 can check White king.', 'White  king on h1 can capture Black rook on h2.']
# ['Black rook on g8 can check White king.', 'White bishop on f4 can check Black king.', 'Black  rook on g8 can capture White rook on g1.']
# ['Black rook on g8 can check White king.', 'White bishop on f4 can check Black king.']
# ['Black rook on g8 can check White king.', 'Black  knight on f3 can capture White rook on g1.', 'Black  rook on g8 can capture White rook on g1.', 'White rook on g1 can check Black king.']
# ['White  rook on b1 can capture Black rook on g1.']
# ['Black  knight on f3 can capture White rook on g1.', 'White rook on g1 can check Black king.']
# ['White  king on h1 can capture Black knight on g1.']
# []
# ['Black pawn on e5 is pinned.']
# ['White bishop on f4 can check Black king.', 'Black pawn on e5 is pinned.']
# ['Black pawn on e5 is pinned.', 'White bishop on f4 can check Black king.']
# ['Black pawn on e5 is pinned.']
# []
# []
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White  bishop on g2 can capture Black knight on c6.']
# ['White knight on f3 can check Black king.', 'White rook on h1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'Black rook on h8 can check White king.', 'White rook on h1 can check Black king.', 'White knight on f3 can check Black king.']
# ['Black knight on f6 can check White king.', 'White knight on f3 can check Black king.', 'Black queen on d8 can check White king.', 'White rook on h1 can check Black king.', 'Black rook on h8 can check White king.']
# ['White rook on h1 can check Black king.', 'Black queen on d8 can check White king.', 'Black rook on h8 can check White king.', 'White knight on f3 can check Black king.', 'Black knight on f6 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White rook on h1 can check Black king.', 'Black  knight on c6 can capture White knight on d4.', 'Black rook on h8 can check White king.']
# ...
# ['Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black rook on f8 can check White king.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.']
# ['Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.']
# ['Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black rook on f8 can check White king.', 'Black knight on f6 can check White king.', 'White rook on f1 can check Black king.']
# ['Black knight on f6 can check White king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black knight on f6 can check White king.', 'White knight on f3 can check Black king.', 'Black rook on f8 can check White king.']
# ['White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black knight on f6 can check White king.', 'Black rook on f8 can check White king.']
# ['Black knight on f6 can check White king.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black rook on f8 can check White king.']
# ['White rook on f1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.']
# ['Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'White knight on f3 can check Black king.']
# ['Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'White knight on f3 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.']
# ['Black  queen on d8 can capture White bishop on d3.', 'White knight on f3 can check Black king.', 'Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'Black  knight on c5 can capture White bishop on d3.']
# ['White rook on f1 can check Black king.', 'White knight on f3 can check Black king.', 'White  queen on c2 can capture Black queen on d3.', 'Black rook on f8 can check White king.']
# ['Black  knight on c5 can capture White queen on d3.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.', 'Black rook on f8 can check White king.']
# ['Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  knight on d3 can capture White bishop on c1.', 'Black rook on f8 can check White king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black knight on f6 can check White king.', 'White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White queen on d1 can check Black king.']
# ['Black knight on f6 can check White king.', 'Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['White queen on d1 can check Black king.', 'Black knight on f6 can check White king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'Black knight on f6 can check White king.', 'White queen on d1 can check Black king.']
# ['Black knight on f6 can check White king.', 'Black queen on d8 can check White king.', 'White queen on d1 can check Black king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'White  knight on c3 can capture Black knight on d5.']
# ['Black queen on d8 can check White king.', 'Black  knight on d5 can capture White knight on c3.', 'White queen on d1 can check Black king.']
# ['White  pawn on b2 can capture Black knight on c3.', 'White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['White queen on d1 can check Black king.', 'Black queen on d8 can check White king.']
# ['Black queen on d8 can check White king.', 'White queen on d1 can check Black king.', 'Black rook on h8 can check White king.']
# ['Black queen on d8 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.', 'Black rook on h8 can check White king.']
# ['White queen on d1 can check Black king.', 'Black rook on h8 can check White king.', 'White knight on f3 can check Black king.', 'Black queen on d8 can check White king.']
# ['White knight on f3 can check Black king.', 'White queen on d1 can check Black king.', 'Black rook on h8 can check White king.', 'Black queen on d8 can check White king.']
# ['Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black rook on f8 can check White king.', 'White rook on h1 can check Black king.', 'White queen on d1 can check Black king.']
# ['White knight on f3 can check Black king.', 'White queen on d1 can check Black king.', 'White rook on h1 can check Black king.', 'Black rook on f8 can check White king.']
# ['White rook on h1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.']
# ['White rook on h1 can check Black king.', 'White queen on d1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.']
# ['White rook on h1 can check Black king.', 'White queen on d1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.']
# ['White rook on h1 can check Black king.', 'White knight on f3 can check Black king.', 'White queen on d1 can check Black king.', 'Black rook on f8 can check White king.']
# ['White rook on f1 can check Black king.', 'Black rook on f8 can check White king.', 'White knight on f3 can check Black king.']
# ['White knight on f3 can check Black king.', 'Black rook on f8 can check White king.', 'White rook on f1 can check Black king.']
# ['Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'White knight on f3 can check Black king.']
# ['White rook on f1 can check Black king.', 'White knight on f3 can check Black king.', 'Black rook on f8 can check White king.', 'Black bishop on g7 can check White king.']
# ['White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.']
# ['Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.']
# ['Black  queen on d8 can capture White knight on g5.', 'White rook on f1 can check Black king.', 'Black rook on f8 can check White king.', 'Black bishop on g7 can check White king.']
# ['White  bishop on e3 can capture Black knight on d4.', 'Black rook on f8 can check White king.', 'Black bishop on g7 can check White king.', 'White  queen on d1 can capture Black knight on d4.', 'White rook on f1 can check Black king.']
# ['Black bishop on g7 can check White king.', 'White rook on f1 can check Black king.', 'Black rook on f8 can check White king.']
# ['Black rook on f8 can check White king.', 'White  pawn on g2 can capture Black bishop on h3.', 'Black bishop on g7 can check White king.', 'White  queen on d1 can capture Black knight on d4.', 'White rook on f1 can check Black king.']
# ['Black rook on f8 can check White king.', 'Black bishop on g7 can check White king.', 'White rook on f1 can check Black king.']
# ['White  queen on d1 can capture Black knight on f3.', 'Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.']
# ['Black rook on f8 can check White king.', 'Black bishop on g7 can check White king.']
# ['Black rook on f8 can check White king.', 'Black bishop on g7 can check White king.']
# ['Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.', 'White rook on f1 can check Black king.']
# ['Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.']
# ['Black bishop on g7 can check White king.', 'Black  queen on c8 can capture White queen on g4.', 'White rook on f1 can check Black king.', 'Black  queen on c8 can capture White bishop on c4.', 'Black rook on f8 can check White king.']
# ['White  queen on g4 can capture Black knight on h4.', 'White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.']
# ['White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.', 'Black  queen on c4 can capture White knight on e4.', 'Black pawn on h7 is pinned.', 'Black rook on f8 can check White king.']
# ['Black bishop on g7 can check White king.', 'Black rook on a8 can check White king.', 'White rook on f1 can check Black king.', 'White  bishop on e3 can capture Black rook on f4.', 'Black pawn on h7 is pinned.']
# ['White rook on f1 can check Black king.', 'Black rook on a8 can check White king.', 'Black pawn on h7 is pinned.', 'Black  pawn on e5 can capture White bishop on f4.', 'Black bishop on g7 can check White king.']
# ['Black bishop on g7 can check White king.', 'Black pawn on h7 is pinned.', 'White rook on f1 can check Black king.', 'Black rook on a8 can check White king.']
# ['Black  bishop on g7 can capture White rook on a1.', 'White rook on f1 can check Black king.', 'Black  queen on c4 can capture White knight on e4.', 'Black bishop on g7 can check White king.', 'Black  queen on c4 can capture White rook on f1.']
# ['Black rook on f8 can check White king.', 'White  queen on f4 can capture Black rook on f8.', 'White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.']
# ['Black rook on f8 can check White king.', 'Black  rook on f8 can capture White queen on f4.', 'White rook on f1 can check Black king.', 'Black  queen on c4 can capture White rook on c1.', 'Black  queen on c4 can capture White rook on f1.']
# ['Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'White  queen on f4 can capture Black rook on f8.', 'White knight on e4 is pinned.']
# ['Black rook on f8 can check White king.', 'White rook on f1 can check Black king.', 'Black bishop on g7 can check White king.', 'White knight on e4 is pinned.', 'Black  queen on d5 can capture White knight on e4.']
# ['Black rook on f8 can check White king.', 'White pawn on h3 is pinned.', 'Black bishop on g7 can check White king.', 'White rook on f1 can check Black king.']
# ['Black rook on f8 can check White king.', 'Black bishop on g7 can check White king.']
# ['Black rook on f8 can check White king.', 'White  queen on e3 can capture Black bishop on h6.']
# ['Black rook on f8 can check White king.']
# ['Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.']
# ['Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.', 'Black  queen on h5 can capture White knight on g5.']
# ['Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.']
# ['Black bishop on g7 can check White king.', 'Black rook on f8 can check White king.']
# ['White  knight on e6 can capture Black bishop on g7.', 'Black rook on e8 can check White king.', 'Black bishop on g7 can check White king.']
# ['Black rook on e8 can check White king.', 'Black  king on h8 can capture White knight on g7.', 'Black  rook on e8 can capture White queen on e3.']
# ['Black rook on e8 can check White king.']
# ['Black  king on h8 can capture White knight on g7.', 'Black  queen on d5 can capture White queen on f3.', 'Black rook on e8 can check White king.', 'White queen on f3 is pinned.', 'White queen on f3 can check Black king.']
# ['White queen on f3 is pinned.', 'White queen on f3 can check Black king.']
# ['Black  queen on d5 can capture White queen on f3.', 'Black  king on h8 can capture White knight on g7.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'White  queen on f3 can capture Black rook on e2.']
# ['Black  pawn on g6 can capture White knight on h5.', 'Black  queen on d2 can capture White rook on c1.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.', 'Black  queen on d2 can capture White queen on c3.']
# ['Black queen on c3 can check White king.', 'White  rook on c1 can capture Black queen on c3.', 'White rook on f1 can check Black king.']
# ['Black  pawn on g6 can capture White knight on h5.', 'White rook on f1 can check Black king.']
# ['White rook on f1 can check Black king.']
# ['White rook on c1 can check Black king.']
# ['White rook on c1 can check Black king.']
# ['White rook on c1 can check Black king.']
# ['White rook on c1 can check Black king.']
# []
# []
# []
# []
# []
# []
# []
# ['Black rook on e6 can check White king.']
# ['Black rook on e6 can check White king.']
# []
# []
# ['White  king on f2 can capture Black rook on e1.']
# []
# ['Black rook on e1 can check White king.', 'White  king on f2 can capture Black rook on e1.']
# []
# []
# []
# []
# []
# []
# []
# []
# ['White rook on c5 can check Black king.']
# ['White rook on c5 can check Black king.']
# ['White pawn on f4 can check Black king.', 'White rook on c5 can check Black king.']
# ['White rook on c5 can check Black king.', 'White pawn on f4 can check Black king.']
# ['White rook on c5 can check Black king.']
# ['White rook on c5 can check Black king.']
# []
# []
# ['White rook on c5 can check Black king.', 'White pawn on f4 can check Black king.']
# ['White rook on c5 can check Black king.', 'White pawn on f4 can check Black king.']
# ['White rook on c6 can check Black king.']
# ['White rook on c6 can check Black king.']
# ['White rook on c6 can check Black king.']
# ['White rook on c6 can check Black king.']
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/lanv/Desktop/trout-ai/captioned-positions-loader/src/main.ipynb Cell 3 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/home/lanv/Desktop/trout-ai/captioned-positions-loader/src/main.ipynb#W2sZmlsZQ%3D%3D?line=40'>41</a>   print(descriptions)
#      <a href='vscode-notebook-cell:/home/lanv/Desktop/trout-ai/captioned-positions-loader/src/main.ipynb#W2sZmlsZQ%3D%3D?line=43'>44</a> # read next game
# ---> <a href='vscode-notebook-cell:/home/lanv/Desktop/trout-ai/captioned-positions-loader/src/main.ipynb#W2sZmlsZQ%3D%3D?line=44'>45</a> game = chess.pgn.read_game(pgn)
#
# File /nix/store/45jh0cwf0n7ii73bazsaz43xs0b2bn5l-python3-3.10.9-env/lib/python3.10/site-packages/chess/pgn.py:1691, in read_game(handle, Visitor)
#    1689         else:
#    1690             visitor.visit_move(board_stack[-1], move)
# -> 1691             board_stack[-1].push(move)
#    1692         visitor.visit_board(board_stack[-1])
#    1694 if fresh_line:
#
# File /nix/store/45jh0cwf0n7ii73bazsaz43xs0b2bn5l-python3-3.10.9-env/lib/python3.10/site-packages/chess/__init__.py:2216, in Board.push(self, move)
#    2213 to_bb = BB_SQUARES[move.to_square]
#    2215 promoted = bool(self.promoted & from_bb)
# -> 2216 piece_type = self._remove_piece_at(move.from_square)
#    2217 assert piece_type is not None, f"push() expects move to be pseudo-legal, but got {move} in {self.board_fen()}"
#    2218 capture_square = move.to_square
#
# KeyboardInterrupt:
